# %%
def computer_generiert_zahlen():
    computer_zahlen = [ [1, 3, 4, 33, 40, 47], [2, 13, 24, 38, 41, 48], [3, 7, 12, 22, 44, 45]]
    return computer_zahlen

# %%
computer_generiert_zahlen ()
# Out:
# [[1, 3, 4, 33, 40, 47], [2, 13, 24, 38, 41, 48], [3, 7, 12, 22, 44, 45]]
